# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import time
import matplotlib.pyplot as plt
import os

from sklearn.model_selection import cross_val_score, GridSearchCV, cross_validate, train_test_split
from sklearn.metrics import accuracy_score, classification_report, f1_score, roc_auc_score, roc_curve, auc
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, KFold, cross_val_score, learning_curve, GridSearchCV, validation_curve

# %% [markdown]
# # Load and preprocess the data

# %%
PATH_TO_DATA = "datasets/"

data1 = pd.read_csv(os.path.join(PATH_TO_DATA, "pulsar_stars.csv"), dtype=np.float32)
Y = np.array(data1.pop("target_class"))
X = np.array(data1)

# X_train = np.loadtxt(os.path.join(PATH_TO_SAMSUNG_DATA, "samsung_train.txt"))
# y_train = np.loadtxt(os.path.join(PATH_TO_SAMSUNG_DATA,
#                                   "samsung_train_labels.txt")).astype(int)

# X_test = np.loadtxt(os.path.join(PATH_TO_SAMSUNG_DATA, "samsung_test.txt"))
# y_test = np.loadtxt(os.path.join(PATH_TO_SAMSUNG_DATA,
#                                   "samsung_test_labels.txt")).astype(int)

# X = np.vstack((X_train, X_test))
# Y = np.concatenate((y_train, y_test))

sc = StandardScaler()
X = sc.fit_transform(X)
print("Shape of input data:",X.shape)
print("Shape of labels:",Y.shape)
random_seed = 1
# Out:
# Shape of input data: (17898, 8)
# Shape of labels: (17898,)

# %% [markdown]
# # Kmeans

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score, adjusted_mutual_info_score
inertia = []
sil = []
ami = []
max_k = 10
for k in range(1, max_k):
    print("k:",k)
    kmeans = KMeans(n_clusters=k, random_state=random_seed, n_jobs = -1).fit(X)
    inertia.append(np.sqrt(kmeans.inertia_))
    if(k > 1):
        sil.append(silhouette_score(X, kmeans.labels_))
        ami.append(adjusted_mutual_info_score(Y, kmeans.labels_, average_method = 'arithmetic'))
plt.plot(range(1, max_k), inertia, marker='s');
plt.title('Inertia vs k: Pulsar dataset')
plt.xlabel('$k$')
plt.ylabel('$Inertia$');
plt.show()

plt.plot(range(2, max_k), sil, marker='s');
plt.title('Silhouette score vs k: Pulsar dataset')
plt.xlabel('$k$')
plt.ylabel('$Silhouette score$');
plt.show()

plt.plot(range(2, max_k), ami, marker='s');
plt.title('Adjusted Mutual Information vs k: Pulsar dataset')
plt.xlabel('$k$')
plt.ylabel('$AMI$ score');
plt.show()
# Out:
# k: 1
# k: 2
# /home/nihar/anaconda3/envs/ML_project3/lib/python3.5/site-packages/sklearn/metrics/pairwise.py:258: RuntimeWarning: invalid value encountered in sqrt
#   return distances if squared else np.sqrt(distances, out=distances)
# /home/nihar/anaconda3/envs/ML_project3/lib/python3.5/site-packages/sklearn/metrics/pairwise.py:258: RuntimeWarning: invalid value encountered in sqrt
#   return distances if squared else np.sqrt(distances, out=distances)
# /home/nihar/anaconda3/envs/ML_project3/lib/python3.5/site-packages/sklearn/metrics/pairwise.py:258: RuntimeWarning: invalid value encountered in sqrt
#   return distances if squared else np.sqrt(distances, out=distances)
# k: 3
# /home/nihar/anaconda3/envs/ML_project3/lib/python3.5/site-packages/sklearn/metrics/pairwise.py:258: RuntimeWarning: invalid value encountered in sqrt
#   return distances if squared else np.sqrt(distances, out=distances)
# ...

# %%
# Use elbow method in Inertia vs k plot for computing best k value
k = 2

# %%
kmeans = KMeans(n_clusters=k, random_state=random_seed, n_jobs = -1)
kmeans.fit(X)
X_kmeans = kmeans.fit_transform(X)
kmeans_labels = kmeans.predict(X)

# %%
print('Inertia: ', kmeans.inertia_)
sil_score = silhouette_score(X, kmeans.labels_)
print('Silhouette score: ', sil_score)
ami_score = adjusted_mutual_info_score(Y, kmeans.labels_, average_method = 'arithmetic')
print('Adjusted Mutual Information (AMI) score: ', ami_score)
# Out:
# Inertia:  92214.36896422021
# /home/nihar/anaconda3/envs/ML_project3/lib/python3.5/site-packages/sklearn/metrics/pairwise.py:258: RuntimeWarning: invalid value encountered in sqrt
#   return distances if squared else np.sqrt(distances, out=distances)
# /home/nihar/anaconda3/envs/ML_project3/lib/python3.5/site-packages/sklearn/metrics/pairwise.py:258: RuntimeWarning: invalid value encountered in sqrt
#   return distances if squared else np.sqrt(distances, out=distances)
# /home/nihar/anaconda3/envs/ML_project3/lib/python3.5/site-packages/sklearn/metrics/pairwise.py:258: RuntimeWarning: invalid value encountered in sqrt
#   return distances if squared else np.sqrt(distances, out=distances)
# Silhouette score:  0.60110605
# Adjusted Mutual Information (AMI) score:  0.4055309587614527

# %%
plt.figure()
plt.hist(kmeans.labels_, bins=np.arange(0, k + 1) - 0.5, rwidth=0.5, zorder=2)
plt.xticks(np.arange(0, k))
plt.xlabel('Cluster label')
plt.ylabel('Number of samples')
plt.title('KMeans Samples vs cluster labels: Pulsar Dataset')
plt.grid()

# %%
from pandas.plotting import table
kmeans_tab = pd.crosstab(Y, kmeans_labels, margins=True)
kmeans_tab.index = ['non-pulsar', 'pulsar','all']
kmeans_tab.columns = ['cluster' + str(i + 1) for i in range(2)] + ['all']
plt.figure()
ax = plt.subplot(111,frameon=True, title = "KMeans Clustering: Pulsar dataset") # no visible frame
ax.axis("off")
table(ax,kmeans_tab, loc = 'upper center');

# %% [markdown]
# # Expectation Maximization

# %%
from sklearn.mixture import GaussianMixture as GMM

aic = []
bic = []
max_components = 10
for components in range(1, max_components):
    print("Components:",components)
    gmm = GMM(n_components=components,covariance_type='full',random_state=random_seed).fit(X)
    aic.append(gmm.aic(X))
    bic.append(gmm.bic(X))

plt.plot(np.arange(1,max_components), bic, label='BIC')
plt.plot(np.arange(1,max_components), aic, label='AIC')
plt.legend(loc='best')
plt.xlabel('components');
plt.ylabel('Score')
plt.title('AIC/BIC vs GMM components: Pulsar Dataset')
# Out:
# Components: 1
# Components: 2
# Components: 3
# Components: 4
# Components: 5
# Components: 6
# Components: 7
# Components: 8
# Components: 9
# Text(0.5, 1.0, 'AIC/BIC vs GMM components: Pulsar Dataset')

# %%
n_best = range(1,max_components)[np.argmin(bic)]
print('Optimal number of components for dataset 1 based on BIC: ', n_best)
# Out:
# Optimal number of components for dataset 1 based on BIC:  9

# %%
gmm = GMM(n_components=n_best,covariance_type='full',random_state=random_seed).fit(X)
gmm_labels = gmm.predict(X)
X_gmm = gmm.predict_proba(X)

# %%
print('BIC: ', gmm.bic(X))
score_gmm = silhouette_score(X, gmm_labels)
print('Silhouette score: ', score_gmm)
ami1_gmm = adjusted_mutual_info_score(Y, gmm_labels, average_method = 'arithmetic')
print('Adjusted Mutual Information (AMI) score: ', ami1_gmm)
# Out:
# BIC:  -147712.8707131595
# /home/nihar/anaconda3/envs/ML_project3/lib/python3.5/site-packages/sklearn/metrics/pairwise.py:258: RuntimeWarning: invalid value encountered in sqrt
#   return distances if squared else np.sqrt(distances, out=distances)
# /home/nihar/anaconda3/envs/ML_project3/lib/python3.5/site-packages/sklearn/metrics/pairwise.py:258: RuntimeWarning: invalid value encountered in sqrt
#   return distances if squared else np.sqrt(distances, out=distances)
# Silhouette score:  0.1020682
# Adjusted Mutual Information (AMI) score:  0.17074110996831807
# /home/nihar/anaconda3/envs/ML_project3/lib/python3.5/site-packages/sklearn/metrics/pairwise.py:258: RuntimeWarning: invalid value encountered in sqrt
#   return distances if squared else np.sqrt(distances, out=distances)

# %%
plt.figure()
plt.hist(gmm_labels, bins=np.arange(0, n_best + 1) - 0.5, rwidth=0.5, zorder=2)
plt.xticks(np.arange(0, n_best))
plt.xlabel('Cluster label')
plt.ylabel('Number of samples')
plt.title('GMM Samples vs cluster labels: Pulsar Dataset')
plt.grid()

# %%
gmm_tab = pd.crosstab(Y, gmm_labels, margins=True)
gmm_tab.index = ['non-pulsar', 'pulsar', 'all']
gmm_tab.columns = ['cluster' + str(i + 1) for i in range(n_best)] + ['all']
plt.figure()
ax = plt.subplot(111,frameon=False, title = "EM Clustering: Pulsar dataset") # no visible frame
ax.axis("off")
table(ax, gmm_tab, loc = 'upper center', colWidths=[0.2]*10);

# %% [markdown]
# # Dimensionality reduction: PCA

# %%
from sklearn.decomposition import PCA
print("Total number of components:", len(X[0]))

pca = PCA(n_components=0.9,random_state = random_seed)
pca.fit(X)
X_reduced_pca = pca.fit_transform(X)

variance = pca.explained_variance_ratio_
print("Number of components that explain 90% variance: ", len(variance))

print("Variance explained by first three components: ",round(variance[0]*100,2),round(variance[1]*100,2), round(variance[2]*100,2))
n_best = len(variance)

dims = range(1,len(X[0]))
mse = []
for dim in dims:
    pca_temp = PCA(n_components=dim,random_state = random_seed)
    X_temp = pca_temp.fit_transform(X)
    X_inverse = pca_temp.inverse_transform(X_temp)
    mse.append(np.sum(np.square(X - X_inverse))/X_inverse.size)
# Out:
# Total number of components: 8
# Number of components that explain 90% variance:  4
# Variance explained by first three components:  51.68 26.81 10.12

# %%
# Plot variance explained by each component to find the best number of components
plt.figure()
plt.plot(np.arange(1, len(pca.singular_values_) + 1), pca.singular_values_)
plt.xticks(np.arange(1, len(pca.singular_values_) + 1))
plt.xlabel('Component')
plt.ylabel('Variance')
plt.title('PCA Eigen Values vs components: Pulsar Dataset')
plt.grid()

plt.figure()
plt.plot(np.arange(1, n_best + 1), np.cumsum(variance))
plt.xticks(np.arange(1, n_best + 1))
plt.xlabel('Component')
plt.ylabel('Variance (cumulative)')
plt.title('PCA Cumulative Variance vs components: Pulsar Dataset')
plt.grid()

plt.figure()
plt.plot(np.arange(1, len(mse) + 1), mse)
plt.xticks(np.arange(1, len(mse) + 1))
plt.xlabel('Component')
plt.ylabel('Reconstruction error')
plt.title('PCA Reconstruction error vs components: Pulsar Dataset')
plt.grid()

# %%
X_inverse = pca.inverse_transform(X_reduced_pca)
mse1 = np.sum(np.square(X - X_inverse))/X_inverse.size
print('PCA Reconstruction mean squared error for Pulsar dataset:', mse1)
# Out:
# PCA Reconstruction mean squared error for Pulsar dataset: 0.056821803724796414

# %%
pca = PCA(n_components=2, random_state = random_seed)
X_2d_pca = pca.fit_transform(X)  
print("Shape of projected data:", X_2d_pca.shape)
plt.scatter(X_2d_pca[:,0], X_2d_pca[:,1],c=Y,s=10);
plt.colorbar()
plt.xlabel('Component 1')
plt.ylabel('Component 2')
plt.title('PCA 2D Projected data: Pulsar Dataset');
# Out:
# Shape of projected data: (17898, 2)

# %% [markdown]
# # Dimensionality Reduction: ICA

# %%
# Compute ICA
from sklearn.decomposition import FastICA

kurt = []
mse = []
print(X.shape[1])
dims = range(1,len(X[0]))
for dim in dims:
    ica = FastICA(n_components=dim, random_state=random_seed, max_iter=1000)
    print(dim)
    tmp = ica.fit_transform(X)
    X_temp = tmp
    tmp = pd.DataFrame(tmp)
    tmp = tmp.kurt(axis=0)
    kurt.append(tmp.abs().mean())
    X_inverse = ica.inverse_transform(X_temp)
    mse.append(np.sum(np.square(X - X_inverse))/X_inverse.size)
    
n_best = dims[np.argmax(kurt)]
print('Optimal number of independent components: ', n_best)

plt.figure()
plt.title("ICA Kurtosis: Pulsar Dataset")
plt.xlabel("Independent Components")
plt.ylabel("Avg Kurtosis Across IC")
plt.plot(dims, kurt, 'b-')
plt.grid(False)
plt.show()

plt.figure()
plt.plot(np.arange(1, len(mse) + 1), mse)
plt.xticks(np.arange(1, len(mse) + 1))
plt.xlabel('Component')
plt.ylabel('Reconstruction error')
plt.title('ICA Reconstruction error vs components: Pulsar Dataset')
plt.grid()
# Out:
# 8
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# Optimal number of independent components:  7

# %%
ica = FastICA(n_components=n_best, random_state=random_seed, max_iter=1000)

X_reduced_ica = ica.fit_transform(X)  # Get the estimated sources
A_ = ica.mixing_.T
X_inverse = ica.inverse_transform(X_reduced_ica)
mse1 = np.sum(np.square(X - X_inverse))/X_inverse.size
print('ICA Reconstruction mean squared error for Pulsar dataset: ', mse1)
# Out:
# ICA Reconstruction mean squared error for Pulsar dataset:  0.002003281397975516

# %%
ica = FastICA(n_components=2, random_state =  random_seed)
X_2d_ica = ica.fit_transform(X)  
plt.scatter(X_2d_ica[:,0], X_2d_ica[:,1],c=Y,s=10);
plt.colorbar()
plt.xlabel('Component 1')
plt.ylabel('Component 2')
plt.title('ICA 2D Projected data: Pulsar Dataset');

# %% [markdown]
# # Dimensionality Reduction: Randomized projections

# %%
from sklearn.random_projection import GaussianRandomProjection
rca = GaussianRandomProjection(n_components = n_best, random_state = random_seed)
X_reduced_rca = rca.fit_transform(X)

# %%
# from itertools import product
# from sklearn.metrics.pairwise import pairwise_distances
# from collections import defaultdict

# def pairwiseDistCorr(X1,X2):
#     assert X1.shape[0] == X2.shape[0]
    
#     d1 = pairwise_distances(X1)
#     d2 = pairwise_distances(X2)
#     return np.corrcoef(d1.ravel(),d2.ravel())[0,1]

# dims = list(range(2,len(X[0])))
# # dims = list(np.arange(2,(X.shape[1]-1),3))
# # dims.append(X.shape[1])
# tmp = defaultdict(dict)

# for i,dim in product(range(5),dims):
#     print(i,dim)
#     rp = GaussianRandomProjection(random_state=random_seed, n_components=dim)
#     tmp[dim][i] = pairwiseDistCorr(rp.fit_transform(X), X)
# tmp = pd.DataFrame(tmp).T
# mean_recon = tmp.mean(axis=1).tolist()
# std_recon = tmp.std(axis=1).tolist()


# fig, ax1 = plt.subplots()
# ax1.plot(dims,mean_recon, 'b-')
# ax1.set_xlabel('Random Components')
# # Make the y-axis label, ticks and tick labels match the line color.
# ax1.set_ylabel('Mean Reconstruction Correlation', color='b')
# ax1.tick_params('y', colors='b')
# plt.grid(False)

# ax2 = ax1.twinx()
# ax2.plot(dims,std_recon, 'm-')
# ax2.set_ylabel('STD Reconstruction Correlation', color='m')
# ax2.tick_params('y', colors='m')
# plt.grid(False)

# plt.title("Random Components for 5 Restarts: Pulsar Dataset")
# fig.tight_layout()
# plt.show()

# %%
rca = GaussianRandomProjection(n_components=2, random_state = random_seed)
X_2d_rca = rca.fit_transform(X)  
plt.scatter(X_2d_rca[:,0], X_2d_rca[:,1],c=Y,s=10);
plt.colorbar()
plt.xlabel('Component 1')
plt.ylabel('Component 2')
plt.title('RCA 2D Projected data: Pulsar Dataset');

# %% [markdown]
# # Dimensionality Reduction: Tree based feature selection

# %%
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.feature_selection import SelectFromModel
clf = ExtraTreesClassifier(n_estimators=50,random_state=random_seed)
clf = clf.fit(X,Y)
tree_model = SelectFromModel(clf, prefit=True)
X_reduced_tree = tree_model.transform(X)
print(X_reduced_tree.shape)
# Out:
# (17898, 3)

# %%
imp = clf.feature_importances_ 
imp = pd.DataFrame(imp,columns=['Feature Importance'])
imp.sort_values(by=['Feature Importance'],inplace=True,ascending=False)
imp['Cum Sum'] = imp['Feature Importance'].cumsum()
imp = imp[imp['Cum Sum']<=0.95]
top_cols = imp.index.tolist()

plt.figure()
plt.bar( np.arange(0, 6) - 0.5,imp['Feature Importance'][:6
].tolist(),alpha=0.5)
plt.xticks(np.arange(0,6),top_cols[:6])
plt.xlabel('Feature number')
plt.ylabel('Feature Importance')
plt.title('Feature Importance: Pulsar Dataset')
plt.grid()

# %%
tree_based = SelectFromModel(clf, max_features = 2, threshold=-np.inf, prefit=True)
X_2d_tree = tree_based.transform(X)  
plt.scatter(X_2d_tree[:,0], X_2d_tree[:,1],c=Y,s=10);
plt.colorbar()
plt.xlabel('Component 1')
plt.ylabel('Component 2')
plt.title('Tree Based 2D Projected data: Pulsar Dataset');

# %% [markdown]
# # PCA with K-means

# %%
inertia = []
sil = []
ami = []
max_k = 10
for k in range(1, max_k):
    print("k:",k)
    kmeans = KMeans(n_clusters=k, random_state=random_seed, n_jobs = -1).fit(X_reduced_pca)
    inertia.append(np.sqrt(kmeans.inertia_))
    if(k > 1):
        sil.append(silhouette_score(X, kmeans.labels_))
        ami.append(adjusted_mutual_info_score(Y, kmeans.labels_, average_method = 'arithmetic'))
plt.plot(range(1, max_k), inertia, marker='s');
plt.title('PCA with KMeans: Inertia vs k: Pulsar dataset')
plt.xlabel('$k$')
plt.ylabel('$Inertia$');
plt.show()

plt.plot(range(2, max_k), sil, marker='s');
plt.title('PCA with KMeans:  Silhouette score vs k: Pulsar dataset')
plt.xlabel('$k$')
plt.ylabel('$Silhouette score$');
plt.show()

plt.plot(range(2, max_k), ami, marker='s');
plt.title('PCA with KMeans: Adjusted Mutual Information vs k: Pulsar dataset')
plt.xlabel('$k$')
plt.ylabel('$AMI$ score');
plt.show()
# Out:
# k: 1
# k: 2
# /home/nihar/anaconda3/envs/ML_project3/lib/python3.5/site-packages/sklearn/metrics/pairwise.py:258: RuntimeWarning: invalid value encountered in sqrt
#   return distances if squared else np.sqrt(distances, out=distances)
# /home/nihar/anaconda3/envs/ML_project3/lib/python3.5/site-packages/sklearn/metrics/pairwise.py:258: RuntimeWarning: invalid value encountered in sqrt
#   return distances if squared else np.sqrt(distances, out=distances)
# /home/nihar/anaconda3/envs/ML_project3/lib/python3.5/site-packages/sklearn/metrics/pairwise.py:258: RuntimeWarning: invalid value encountered in sqrt
#   return distances if squared else np.sqrt(distances, out=distances)
# k: 3
# /home/nihar/anaconda3/envs/ML_project3/lib/python3.5/site-packages/sklearn/metrics/pairwise.py:258: RuntimeWarning: invalid value encountered in sqrt
#   return distances if squared else np.sqrt(distances, out=distances)
# ...

# %%
k = 2
kmeans = KMeans(n_clusters=k,n_init=100,random_state=random_seed).fit(X_2d_pca)
X_clustered = kmeans.predict(X_2d_pca)
print(X_clustered.shape)
plt.scatter(X_2d_pca[:,0], X_2d_pca[:,1], c=X_clustered,s=20);
plt.colorbar()
plt.xlabel('Component 1')
plt.ylabel('Component 2')
plt.title('PCA with Kmeans on 2d data: Pulsar Dataset');
# Out:
# (17898,)

# %%
kmeans = KMeans(n_clusters=k,n_init=100,random_state=random_seed).fit(X_reduced_pca)
X_clustered = kmeans.predict(X_reduced_pca)
X_clustered_pca_kmeans = kmeans.fit_transform(X_reduced_pca)

tab = pd.crosstab(Y, X_clustered, margins=True)
tab.index = ['non-pulsar','pulsar', 'all']
tab.columns = ['cluster' + str(i + 1) for i in range(k)] + ['all']
plt.figure()
ax = plt.subplot(111,frameon=False, title = "PCA with KMeans: Pulsar dataset") # no visible frame
ax.axis("off")
table(ax, tab, loc = 'upper center');

# %%
# k = 2
# kmeans = KMeans(n_clusters=k,n_init=100,random_state=random_seed).fit(X_reduced_pca)
# X_clustered = kmeans.predict(X_reduced_pca)
# tab = pd.crosstab(Y, X_clustered, margins=True)
# tab.index = ['walking', 'going up the stairs',
#             'going down the stairs', 'sitting', 'standing', 'laying', 'all']
# tab.columns = ['cluster' + str(i + 1) for i in range(k)] + ['all']
# plt.figure()
# ax = plt.subplot(111,frameon=False) # no visible frame
# ax.axis("off")
# table(ax, tab, loc = 'center')

# %% [markdown]
# # ICA with K-means

# %%
inertia = []
sil = []
ami = []
max_k = 10
for k in range(1, max_k):
    print("k:",k)
    kmeans = KMeans(n_clusters=k, random_state=random_seed, n_jobs = -1).fit(X_reduced_ica)
    inertia.append(np.sqrt(kmeans.inertia_))
    if(k > 1):
        sil.append(silhouette_score(X, kmeans.labels_))
        ami.append(adjusted_mutual_info_score(Y, kmeans.labels_, average_method = 'arithmetic'))
plt.plot(range(1, max_k), inertia, marker='s');
plt.title('ICA with KMeans: Inertia vs k: Pulsar dataset')
plt.xlabel('$k$')
plt.ylabel('$Inertia$');
plt.show()

plt.plot(range(2, max_k), sil, marker='s');
plt.title('ICA with KMeans:  Silhouette score vs k: Pulsar dataset')
plt.xlabel('$k$')
plt.ylabel('$Silhouette score$');
plt.show()

plt.plot(range(2, max_k), ami, marker='s');
plt.title('ICA with KMeans: Adjusted Mutual Information vs k: Pulsar dataset')
plt.xlabel('$k$')
plt.ylabel('$AMI$ score');
plt.show()
# Out:
# k: 1
# k: 2
# /home/nihar/anaconda3/envs/ML_project3/lib/python3.5/site-packages/sklearn/metrics/pairwise.py:258: RuntimeWarning: invalid value encountered in sqrt
#   return distances if squared else np.sqrt(distances, out=distances)
# /home/nihar/anaconda3/envs/ML_project3/lib/python3.5/site-packages/sklearn/metrics/pairwise.py:258: RuntimeWarning: invalid value encountered in sqrt
#   return distances if squared else np.sqrt(distances, out=distances)
# /home/nihar/anaconda3/envs/ML_project3/lib/python3.5/site-packages/sklearn/metrics/pairwise.py:258: RuntimeWarning: invalid value encountered in sqrt
#   return distances if squared else np.sqrt(distances, out=distances)
# k: 3
# /home/nihar/anaconda3/envs/ML_project3/lib/python3.5/site-packages/sklearn/metrics/pairwise.py:258: RuntimeWarning: invalid value encountered in sqrt
#   return distances if squared else np.sqrt(distances, out=distances)
# ...

# %%
k = 2
kmeans = KMeans(n_clusters=k,n_init=100,random_state=random_seed).fit(X_2d_ica)
X_clustered = kmeans.predict(X_2d_ica)
print(X_clustered.shape)
plt.scatter(X_2d_ica[:,0], X_2d_ica[:,1], c=X_clustered,s=20);
plt.colorbar()
plt.xlabel('Component 1')
plt.ylabel('Component 2')
plt.title('ICA with Kmeans on 2d data: Pulsar Dataset');
# Out:
# (17898,)

# %%
kmeans = KMeans(n_clusters=k,n_init=100,random_state=random_seed).fit(X_reduced_ica)
X_clustered = kmeans.predict(X_reduced_ica)
X_clustered_ica_kmeans = kmeans.fit_transform(X_reduced_ica)

tab = pd.crosstab(Y, X_clustered, margins=True)
tab.index = ['non-pulsar','pulsar','all']
tab.columns = ['cluster' + str(i + 1) for i in range(k)] + ['all']
plt.figure()
ax = plt.subplot(111,frameon=False, title = "ICA with Kmeans Clustering: Pulsar dataset") # no visible frame
ax.axis("off")
table(ax, tab, loc = 'upper center');

# %%
# k = 2
# kmeans = KMeans(n_clusters=k,n_init=100,random_state=random_seed).fit(X_reduced_ica)
# X_clustered = kmeans.predict(X_reduced_ica)
# tab = pd.crosstab(Y, X_clustered, margins=True)
# tab.index = ['walking', 'going up the stairs',
#             'going down the stairs', 'sitting', 'standing', 'laying', 'all']
# tab.columns = ['cluster' + str(i + 1) for i in range(k)] + ['all']
# plt.figure()
# ax = plt.subplot(111,frameon=False) # no visible frame
# ax.axis("off")
# table(ax, tab, loc = 'center')

# %% [markdown]
# # RCA with K-means

# %%
inertia = []
sil = []
ami = []
max_k = 10
for k in range(1, max_k):
    print("k:",k)
    kmeans = KMeans(n_clusters=k, random_state=random_seed, n_jobs = -1).fit(X_reduced_rca)
    inertia.append(np.sqrt(kmeans.inertia_))
    if(k > 1):
        sil.append(silhouette_score(X, kmeans.labels_))
        ami.append(adjusted_mutual_info_score(Y, kmeans.labels_, average_method = 'arithmetic'))
plt.plot(range(1, max_k), inertia, marker='s');
plt.title('RCA with KMeans: Inertia vs k: Pulsar dataset')
plt.xlabel('$k$')
plt.ylabel('$Inertia$');
plt.show()

plt.plot(range(2, max_k), sil, marker='s');
plt.title('RCA with KMeans:  Silhouette score vs k: Pulsar dataset')
plt.xlabel('$k$')
plt.ylabel('$Silhouette score$');
plt.show()

plt.plot(range(2, max_k), ami, marker='s');
plt.title('RCA with KMeans: Adjusted Mutual Information vs k: Pulsar dataset')
plt.xlabel('$k$')
plt.ylabel('$AMI$ score');
plt.show()
# Out:
# k: 1
# k: 2
# /home/nihar/anaconda3/envs/ML_project3/lib/python3.5/site-packages/sklearn/metrics/pairwise.py:258: RuntimeWarning: invalid value encountered in sqrt
#   return distances if squared else np.sqrt(distances, out=distances)
# /home/nihar/anaconda3/envs/ML_project3/lib/python3.5/site-packages/sklearn/metrics/pairwise.py:258: RuntimeWarning: invalid value encountered in sqrt
#   return distances if squared else np.sqrt(distances, out=distances)
# /home/nihar/anaconda3/envs/ML_project3/lib/python3.5/site-packages/sklearn/metrics/pairwise.py:258: RuntimeWarning: invalid value encountered in sqrt
#   return distances if squared else np.sqrt(distances, out=distances)
# k: 3
# /home/nihar/anaconda3/envs/ML_project3/lib/python3.5/site-packages/sklearn/metrics/pairwise.py:258: RuntimeWarning: invalid value encountered in sqrt
#   return distances if squared else np.sqrt(distances, out=distances)
# ...

# %%
k = 2
kmeans = KMeans(n_clusters=k,n_init=100,random_state=random_seed).fit(X_2d_rca)
X_clustered = kmeans.predict(X_2d_rca)

print(X_clustered.shape)
plt.scatter(X_2d_rca[:,0], X_2d_rca[:,1], c=X_clustered,s=20);
plt.colorbar()
plt.title('RCA with Kmeans on 2d data: Pulsar Dataset');
# Out:
# (17898,)

# %%
kmeans = KMeans(n_clusters=k,n_init=100,random_state=random_seed).fit(X_reduced_rca)
X_clustered = kmeans.predict(X_reduced_rca)
X_clustered_rca_kmeans = kmeans.fit_transform(X_reduced_rca)

tab = pd.crosstab(Y, X_clustered, margins=True)
tab.index = ['non-pulsar','pulsar', 'all']
tab.columns = ['cluster' + str(i + 1) for i in range(k)] + ['all']
plt.figure()
ax = plt.subplot(111,frameon=False, title = "RCA with KMeans Clustering: Pulsar dataset") # no visible frame
ax.axis("off")
table(ax, tab, loc = 'upper center');

# %%
print(X_reduced_rca.shape)
# k = 2
# kmeans = KMeans(n_clusters=k,n_init=100,random_state = random_seed).fit(X_reduced_rca)
# X_clustered = kmeans.predict(X_reduced_rca)
# tab = pd.crosstab(Y, X_clustered, margins=True)
# tab.index = ['walking', 'going up the stairs',
#             'going down the stairs', 'sitting', 'standing', 'laying', 'all']
# tab.columns = ['cluster' + str(i + 1) for i in range(k)] + ['all']
# plt.figure()
# ax = plt.subplot(111,frameon=False) # no visible frame
# ax.axis("off")
# table(ax, tab, loc = 'center')
# Out:
# (17898, 7)

# %% [markdown]
# # Tree-based feature selection with K-means

# %%
inertia = []
sil = []
ami = []
max_k = 10
for k in range(1, max_k):
    print("k:",k)
    kmeans = KMeans(n_clusters=k, random_state=random_seed, n_jobs = -1).fit(X_reduced_tree)
    inertia.append(np.sqrt(kmeans.inertia_))
    if(k > 1):
        sil.append(silhouette_score(X, kmeans.labels_))
        ami.append(adjusted_mutual_info_score(Y, kmeans.labels_, average_method = 'arithmetic'))
plt.plot(range(1, max_k), inertia, marker='s');
plt.title('Tree based with KMeans: Inertia vs k: Pulsar dataset')
plt.xlabel('$k$')
plt.ylabel('$Inertia$');
plt.show()

plt.plot(range(2, max_k), sil, marker='s');
plt.title('Tree based with KMeans:  Silhouette score vs k: Pulsar dataset')
plt.xlabel('$k$')
plt.ylabel('$Silhouette score$');
plt.show()

plt.plot(range(2, max_k), ami, marker='s');
plt.title('Tree based with KMeans: Adjusted Mutual Information vs k: Pulsar dataset')
plt.xlabel('$k$')
plt.ylabel('$AMI$ score');
plt.show()
# Out:
# k: 1
# k: 2
# /home/nihar/anaconda3/envs/ML_project3/lib/python3.5/site-packages/sklearn/metrics/pairwise.py:258: RuntimeWarning: invalid value encountered in sqrt
#   return distances if squared else np.sqrt(distances, out=distances)
# /home/nihar/anaconda3/envs/ML_project3/lib/python3.5/site-packages/sklearn/metrics/pairwise.py:258: RuntimeWarning: invalid value encountered in sqrt
#   return distances if squared else np.sqrt(distances, out=distances)
# /home/nihar/anaconda3/envs/ML_project3/lib/python3.5/site-packages/sklearn/metrics/pairwise.py:258: RuntimeWarning: invalid value encountered in sqrt
#   return distances if squared else np.sqrt(distances, out=distances)
# k: 3
# /home/nihar/anaconda3/envs/ML_project3/lib/python3.5/site-packages/sklearn/metrics/pairwise.py:258: RuntimeWarning: invalid value encountered in sqrt
#   return distances if squared else np.sqrt(distances, out=distances)
# ...

# %%
k = 2
kmeans = KMeans(n_clusters=k,n_init=100,random_state=random_seed).fit(X_2d_tree)
X_clustered = kmeans.predict(X_2d_tree)
print(X_clustered.shape)
plt.scatter(X_2d_tree[:,0], X_2d_tree[:,1], c=X_clustered,s=20);
plt.colorbar()
plt.title('Tree based with Kmeans on 2d data: Pulsar Dataset');
# Out:
# (17898,)

# %%
kmeans = KMeans(n_clusters=k,n_init=100,random_state=random_seed).fit(X_reduced_tree)
X_clustered = kmeans.predict(X_reduced_tree)
X_clustered_tree_kmeans = kmeans.fit_transform(X_reduced_tree)

tab = pd.crosstab(Y, X_clustered, margins=True)
tab.index = ['non-pulsar','pulsar', 'all']
tab.columns = ['cluster' + str(i + 1) for i in range(k)] + ['all']
plt.figure()
ax = plt.subplot(111,frameon=False, title = "Tree based with KMeans Clustering: Pulsar dataset") # no visible frame
ax.axis("off")
table(ax, tab, loc = 'upper center');

# %%
# components = 6
# gmm = GMM(n_components=components,covariance_type='full',random_state=1).fit(X_reduced)
# X_clustered = gmm.predict(X_reduced)

# plt.scatter(X_reduced[:,0], X_reduced[:,1], c=X_clustered,s=20);
# plt.colorbar()

# %%
# tab = pd.crosstab(Y, X_clustered, margins=True)
# tab.index = ['walking', 'going up the stairs',
#             'going down the stairs', 'sitting', 'standing', 'laying', 'all']
# tab.columns = ['cluster' + str(i + 1) for i in range(6)] + ['all']
# tab

# %%
# components = 2
# gmm = GMM(n_components=components,covariance_type='full',random_state=1).fit(X_reduced)
# X_clustered = gmm.predict(X_reduced)

# plt.scatter(X_reduced[:,0], X_reduced[:,1], c=X_clustered,s=20);
# plt.colorbar()

# %% [markdown]
# # PCA with Expectation Maximization

# %%
components = 2
gmm = GMM(n_components=components,covariance_type='full',random_state=random_seed).fit(X_2d_pca)
X_clustered = gmm.predict(X_2d_pca)
plt.scatter(X_2d_pca[:,0], X_2d_pca[:,1], c=X_clustered,s=20);
plt.colorbar()
plt.xlabel('Component 1')
plt.ylabel('Component 2')
plt.title('PCA with EM on 2d data: Pulsar Dataset');

# %%
gmm = GMM(n_components=components,covariance_type='full',random_state=random_seed).fit(X_reduced_pca)
X_clustered = gmm.predict(X_reduced_pca)
X_clustered_pca_em = gmm.predict_proba(X_reduced_pca)

tab = pd.crosstab(Y, X_clustered, margins=True)
tab.index = ['non-pulsar','pulsar', 'all']
tab.columns = ['cluster' + str(i + 1) for i in range(components)] + ['all']
plt.figure()
ax = plt.subplot(111,frameon=False, title = "PCA with EM Clustering: Pulsar dataset") # no visible frame
ax.axis("off")
table(ax, tab, loc = 'upper center')

# %%
# components = 2
# gmm = GMM(n_components=components,covariance_type='full',random_state=random_seed).fit(X_reduced_pca)
# X_clustered = gmm.predict(X_reduced_pca)
# tab = pd.crosstab(Y, X_clustered, margins=True)
# tab.index = ['walking', 'going up the stairs',
#             'going down the stairs', 'sitting', 'standing', 'laying', 'all']
# tab.columns = ['cluster' + str(i + 1) for i in range(k)] + ['all']
# plt.figure()
# ax = plt.subplot(111,frameon=False) # no visible frame
# ax.axis("off")
# table(ax, tab, loc = 'center')

# %% [markdown]
# # ICA with Expectation Maximization

# %%
components = 2
gmm = GMM(n_components=components,covariance_type='full',random_state=random_seed).fit(X_2d_ica)
X_clustered = gmm.predict(X_2d_ica)

plt.scatter(X_2d_ica[:,0], X_2d_ica[:,1], c=X_clustered,s=20);
plt.colorbar()
plt.xlabel('Component 1')
plt.ylabel('Component 2')
plt.title('ICA with EM on 2d data: Pulsar Dataset');

# %%
components = 2
gmm = GMM(n_components=components,covariance_type='full',random_state=random_seed).fit(X_reduced_ica)
X_clustered = gmm.predict(X_reduced_ica)
X_clustered_ica_em = gmm.predict_proba(X_reduced_ica)

tab = pd.crosstab(Y, X_clustered, margins=True)
tab.index = ['non-pulsar','pulsar', 'all']
tab.columns = ['cluster' + str(i + 1) for i in range(components)] + ['all']
plt.figure()
ax = plt.subplot(111,frameon=False, title = "ICA with EM Clustering: Pulsar dataset") # no visible frame
ax.axis("off")
table(ax, tab, loc = 'upper center');

# %%
# components = 2
# gmm = GMM(n_components=components,covariance_type='full',random_state=random_seed).fit(X_reduced_ica)
# X_clustered = gmm.predict(X_reduced_ica)
# tab = pd.crosstab(Y, X_clustered, margins=True)
# tab.index = ['non-pulsar','pulsar', 'all']
# tab.columns = ['cluster' + str(i + 1) for i in range(components)] + ['all']
# plt.figure()
# ax = plt.subplot(111,frameon=False) # no visible frame
# ax.axis("off")
# table(ax, tab, loc = 'center')

# %% [markdown]
# # RCA with Expectation Maximization

# %%
components = 2
gmm = GMM(n_components=components,covariance_type='full',random_state=random_seed).fit(X_2d_rca)
X_clustered = gmm.predict(X_2d_rca)

plt.scatter(X_2d_rca[:,0], X_2d_rca[:,1], c=X_clustered,s=20);
plt.colorbar()
plt.xlabel('Component 1')
plt.ylabel('Component 2')
plt.title('RCA with EM on 2d data: Pulsar Dataset');

# %%
components = 2
gmm = GMM(n_components=components,covariance_type='full',random_state=random_seed).fit(X_reduced_rca)
X_clustered = gmm.predict(X_reduced_rca)
X_clustered_rca_em = gmm.predict_proba(X_reduced_rca)

tab = pd.crosstab(Y, X_clustered, margins=True)
tab.index = ['non-pulsar','pulsar', 'all']
tab.columns = ['cluster' + str(i + 1) for i in range(components)] + ['all']
plt.figure()
ax = plt.subplot(111,frameon=False, title = "RCA with EM Clustering: Pulsar dataset") # no visible frame
ax.axis("off")
table(ax, tab, loc = 'upper center');

# %%
# components = 2
# gmm = GMM(n_components=components,covariance_type='full',random_state=random_seed).fit(X_reduced_rca)
# X_clustered = gmm.predict(X_reduced_rca)
# tab = pd.crosstab(Y, X_clustered, margins=True)
# tab.index = ['non-pulsar','pulsar', 'all']
# tab.columns = ['cluster' + str(i + 1) for i in range(components)] + ['all']
# plt.figure()
# ax = plt.subplot(111,frameon=False) # no visible frame
# ax.axis("off")
# table(ax, tab, loc = 'center')

# %% [markdown]
# # Feature Selector with Expectation Maximization

# %%
components = 2
gmm = GMM(n_components=components,covariance_type='full',random_state=random_seed).fit(X_2d_tree)
X_clustered = gmm.predict(X_2d_tree)

plt.scatter(X_2d_tree[:,0], X_2d_tree[:,1], c=X_clustered,s=20);
plt.colorbar()
plt.xlabel('Component 1')
plt.ylabel('Component 2')
plt.title('Tree based with EM on 2d data: Pulsar Dataset');

# %%
components = 2
gmm = GMM(n_components=components,covariance_type='full',random_state=random_seed).fit(X_reduced_tree)
X_clustered = gmm.predict(X_reduced_tree)
X_clustered_tree_em = gmm.predict_proba(X_reduced_tree)

tab = pd.crosstab(Y, X_clustered, margins=True)
tab.index = ['non-pulsar','pulsar', 'all']
tab.columns = ['cluster' + str(i + 1) for i in range(components)] + ['all']
plt.figure()
ax = plt.subplot(111,frameon=False, title = "Tree based with EM Clustering: Pulsar dataset") # no visible frame
ax.axis("off")
table(ax, tab, loc = 'upper center');

# %% [markdown]
# # Neural Network on PCA

# %%
from sklearn.model_selection import cross_val_score, GridSearchCV, cross_validate, train_test_split
from sklearn.metrics import accuracy_score, classification_report, f1_score, roc_auc_score, roc_curve, auc
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, KFold, cross_val_score, learning_curve, GridSearchCV, validation_curve
x_train_norm, x_test_norm, y_train, y_test = train_test_split( X_reduced_pca, Y, test_size = 0.3)
seed = 1
n_cv = 5

nn = MLPClassifier(max_iter=2000,early_stopping=True,learning_rate='adaptive',random_state=seed)
hidden_layers = [(100,75,50), (100,75,75,50),(100,75,75,50,50),(100,75,75,50,50,25),(100,75,75,50,50,25,25)]
train_scores, test_scores = validation_curve(nn, x_train_norm, y_train, param_name="hidden_layer_sizes", param_range=hidden_layers, cv=n_cv, n_jobs=-1)

plt.figure()
plt.plot(range(3,len(hidden_layers)+3), np.mean(train_scores, axis=1), label='Training score')
plt.plot(range(3,len(hidden_layers)+3), np.mean(test_scores, axis=1), label='Cross-validation score')
plt.title('NN on PCA - Pulsar Dataset')
plt.xlabel('number of layers')
plt.ylabel("Score")
plt.legend(loc="best")
plt.grid()
plt.show()

# %%
parameters = {'hidden_layer_sizes' : hidden_layers}
nn = MLPClassifier(max_iter=2000 ,early_stopping=True)
clf = GridSearchCV(nn, param_grid=parameters, cv=n_cv, n_jobs=-1)
clf.fit(x_train_norm, y_train)

print("Best parameters for Neural Network:")
print(clf.best_params_)
y_pred = clf.predict(x_test_norm)
print('Accuracy score of Neural network with best parameters is %.2f%%' % (accuracy_score(y_test, y_pred) * 100))
print('ROC score of Neural Network with best parameters is %.2f%%' % (roc_auc_score(y_test, y_pred) * 100))
print('F1 score of Neural Network with best parameters is %.2f%%' % (f1_score(y_test, y_pred) * 100))

train_sizes=np.linspace(0.2, 1.0, 5)
nn = MLPClassifier(max_iter=2000,early_stopping=True,learning_rate='adaptive',random_state=seed
                   ,hidden_layer_sizes = clf.best_params_['hidden_layer_sizes'])
train_sizes, train_scores, test_scores = learning_curve(nn, x_train_norm, y_train, cv=n_cv, train_sizes=train_sizes, n_jobs = -1)

train_scores_mean = np.mean(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)
plt.figure()
plt.title("NN on PCA Learning Curve - Pulsar Dataset")
plt.xlabel("Length of dataset")
plt.ylabel("Score")
plt.grid()
plt.plot(train_sizes, train_scores_mean, label="Training score")
plt.plot(train_sizes, test_scores_mean, label="Cross-validation score")
plt.legend(loc="best")
plt.show()
# Out:
# Best parameters for Neural Network:
# {'hidden_layer_sizes': (100, 75, 75, 50, 50, 25, 25)}
# Accuracy score of Neural network with best parameters is 97.47%
# ROC score of Neural Network with best parameters is 89.56%
# F1 score of Neural Network with best parameters is 85.89%

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)

plt.title('Receiver Operating Characteristic for NN on PCA')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
# Out:
# Text(0.5, 0, 'False Positive Rate')

# %%
X_train, X_test, y_train, y_test = train_test_split( X_reduced_pca, Y, test_size = 0.3)
nn = MLPClassifier(max_iter=2000,early_stopping=True,learning_rate='adaptive',random_state=random_seed
                   ,hidden_layer_sizes = [100, 75, 75, 50, 50])
# %timeit nn.fit(x_train_norm, y_train)

# %timeit nn.predict(x_train_norm)
# Out:
# 1.92 s ± 271 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 52.8 ms ± 3.9 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# # Neural Network on ICA

# %%
x_train_norm, x_test_norm, y_train, y_test = train_test_split( X_reduced_ica, Y, test_size = 0.3)
seed = 1
n_cv = 5

nn = MLPClassifier(max_iter=2000,early_stopping=True,learning_rate='adaptive',random_state=random_seed)
hidden_layers = [(100,75,50), (100,75,75,50),(100,75,75,50,50),(100,75,75,50,50,25),(100,75,75,50,50,25,25)]
train_scores, test_scores = validation_curve(nn, x_train_norm, y_train, param_name="hidden_layer_sizes", param_range=hidden_layers, cv=n_cv, n_jobs=-1)

plt.figure()
plt.plot(range(3,len(hidden_layers)+3), np.mean(train_scores, axis=1), label='Training score')
plt.plot(range(3,len(hidden_layers)+3), np.mean(test_scores, axis=1), label='Cross-validation score')
plt.title('NN on ICA - Pulsar Dataset')
plt.xlabel('number of layers')
plt.ylabel("Score")
plt.legend(loc="best")
plt.grid()
plt.show()

# %%
parameters = {'hidden_layer_sizes' : hidden_layers}
nn = MLPClassifier(max_iter=2000 ,early_stopping=True)
clf = GridSearchCV(nn, param_grid=parameters, cv=n_cv, n_jobs=-1)
clf.fit(x_train_norm, y_train)

print("Best parameters for Neural Network:")
print(clf.best_params_)
y_pred = clf.predict(x_test_norm)
print('Accuracy score of Neural network with best parameters is %.2f%%' % (accuracy_score(y_test, y_pred) * 100))
print('ROC score of Neural Network with best parameters is %.2f%%' % (roc_auc_score(y_test, y_pred) * 100))
print('F1 score of Neural Network with best parameters is %.2f%%' % (f1_score(y_test, y_pred) * 100))

train_sizes=np.linspace(0.2, 1.0, 5)
nn = MLPClassifier(max_iter=2000,early_stopping=True,learning_rate='adaptive',random_state=seed
                   ,hidden_layer_sizes = clf.best_params_['hidden_layer_sizes'])
train_sizes, train_scores, test_scores = learning_curve(nn, x_train_norm, y_train, cv=n_cv, train_sizes=train_sizes, n_jobs = -1)

train_scores_mean = np.mean(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)
plt.figure()
plt.title("NN on ICA Learning Curve - Pulsar Dataset")
plt.xlabel("Length of dataset")
plt.ylabel("Score")
plt.grid()
plt.plot(train_sizes, train_scores_mean, label="Training score")
plt.plot(train_sizes, test_scores_mean, label="Cross-validation score")
plt.legend(loc="best")
plt.show()
# Out:
# Best parameters for Neural Network:
# {'hidden_layer_sizes': (100, 75, 75, 50, 50)}
# Accuracy score of Neural network with best parameters is 97.73%
# ROC score of Neural Network with best parameters is 91.60%
# F1 score of Neural Network with best parameters is 86.99%

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)

plt.title('Receiver Operating Characteristic for NN on ICA')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
# Out:
# Text(0.5, 0, 'False Positive Rate')

# %%
X_train, X_test, y_train, y_test = train_test_split( X_reduced_ica, Y, test_size = 0.3)
nn = MLPClassifier(max_iter=2000,early_stopping=True,learning_rate='adaptive',random_state=random_seed
                   ,hidden_layer_sizes = [100, 75, 75, 50, 50])
# %timeit nn.fit(x_train_norm, y_train)

# %timeit nn.predict(x_train_norm)
# Out:
# 1.51 s ± 244 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 104 ms ± 8.34 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# # Neural Network on RCA

# %%
x_train_norm, x_test_norm, y_train, y_test = train_test_split( X_reduced_rca, Y, test_size = 0.3)
seed = 1
n_cv = 5

nn = MLPClassifier(max_iter=2000,early_stopping=True,learning_rate='adaptive',random_state=seed)
hidden_layers = [(100,75,50), (100,75,75,50),(100,75,75,50,50),(100,75,75,50,50,25),(100,75,75,50,50,25,25)]
train_scores, test_scores = validation_curve(nn, x_train_norm, y_train, param_name="hidden_layer_sizes", param_range=hidden_layers, cv=n_cv, n_jobs=-1)

plt.figure()
plt.plot(range(3,len(hidden_layers)+3), np.mean(train_scores, axis=1), label='Training score')
plt.plot(range(3,len(hidden_layers)+3), np.mean(test_scores, axis=1), label='Cross-validation score')
plt.title('NN on RCA - Pulsar Dataset')
plt.xlabel('number of layers')
plt.ylabel("Score")
plt.legend(loc="best")
plt.grid()
plt.show()

# %%
parameters = {'hidden_layer_sizes' : hidden_layers}
nn = MLPClassifier(max_iter=2000 ,early_stopping=True)
clf = GridSearchCV(nn, param_grid=parameters, cv=n_cv, n_jobs=-1)
clf.fit(x_train_norm, y_train)

print("Best parameters for Neural Network:")
print(clf.best_params_)
y_pred = clf.predict(x_test_norm)
print('Accuracy score of Neural network with best parameters is %.2f%%' % (accuracy_score(y_test, y_pred) * 100))
print('ROC score of Neural Network with best parameters is %.2f%%' % (roc_auc_score(y_test, y_pred) * 100))
print('F1 score of Neural Network with best parameters is %.2f%%' % (f1_score(y_test, y_pred) * 100))

train_sizes=np.linspace(0.2, 1.0, 5)
nn = MLPClassifier(max_iter=2000,early_stopping=True,learning_rate='adaptive',random_state=seed
                   ,hidden_layer_sizes = clf.best_params_['hidden_layer_sizes'])
train_sizes, train_scores, test_scores = learning_curve(nn, x_train_norm, y_train, cv=n_cv, train_sizes=train_sizes, n_jobs = -1)

train_scores_mean = np.mean(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)
plt.figure()
plt.title("NN on RCA Learning Curve - Pulsar Dataset")
plt.xlabel("Length of dataset")
plt.ylabel("Score")
plt.grid()
plt.plot(train_sizes, train_scores_mean, label="Training score")
plt.plot(train_sizes, test_scores_mean, label="Cross-validation score")
plt.legend(loc="best")
plt.show()
# Out:
# Best parameters for Neural Network:
# {'hidden_layer_sizes': (100, 75, 75, 50)}
# Accuracy score of Neural network with best parameters is 98.04%
# ROC score of Neural Network with best parameters is 92.15%
# F1 score of Neural Network with best parameters is 89.16%

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)

plt.title('Receiver Operating Characteristic for NN on RCA')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
# Out:
# Text(0.5, 0, 'False Positive Rate')

# %%
X_train, X_test, y_train, y_test = train_test_split( X_reduced_rca, Y, test_size = 0.3)
sc = StandardScaler()
x_train_norm = sc.fit_transform(X_train)
x_test_norm = sc.transform(X_test)
nn = MLPClassifier(max_iter=2000,early_stopping=True,learning_rate='adaptive',random_state=seed
                   ,hidden_layer_sizes = [100, 75, 75, 50, 50])
# %timeit nn.fit(x_train_norm, y_train)

# %timeit nn.predict(x_train_norm)
# Out:
# 2.79 s ± 1.57 s per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 53.6 ms ± 5.49 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# # Neural Network on Tree based feature selector

# %%
x_train_norm, x_test_norm, y_train, y_test = train_test_split( X_reduced_tree, Y, test_size = 0.3)
seed = 1
n_cv = 5

nn = MLPClassifier(max_iter=2000,early_stopping=True,learning_rate='adaptive',random_state=seed)
hidden_layers = [(100,75,50), (100,75,75,50),(100,75,75,50,50),(100,75,75,50,50,25),(100,75,75,50,50,25,25)]
train_scores, test_scores = validation_curve(nn, x_train_norm, y_train, param_name="hidden_layer_sizes", param_range=hidden_layers, cv=n_cv, n_jobs=-1)

plt.figure()
plt.plot(range(3,len(hidden_layers)+3), np.mean(train_scores, axis=1), label='Training score')
plt.plot(range(3,len(hidden_layers)+3), np.mean(test_scores, axis=1), label='Cross-validation score')
plt.title('NN on Tree Based Feature selector - Pulsar Dataset')
plt.xlabel('number of layers')
plt.ylabel("Score")
plt.legend(loc="best")
plt.grid()
plt.show()

# %%
parameters = {'hidden_layer_sizes' : hidden_layers}
nn = MLPClassifier(max_iter=2000 ,early_stopping=True)
clf = GridSearchCV(nn, param_grid=parameters, cv=n_cv, n_jobs=-1)
clf.fit(x_train_norm, y_train)

print("Best parameters for Neural Network:")
print(clf.best_params_)
y_pred = clf.predict(x_test_norm)
print('Accuracy score of Neural network with best parameters is %.2f%%' % (accuracy_score(y_test, y_pred) * 100))
print('ROC score of Neural Network with best parameters is %.2f%%' % (roc_auc_score(y_test, y_pred) * 100))
print('F1 score of Neural Network with best parameters is %.2f%%' % (f1_score(y_test, y_pred) * 100))

train_sizes=np.linspace(0.2, 1.0, 5)
nn = MLPClassifier(max_iter=2000,early_stopping=True,learning_rate='adaptive',random_state=seed
                   ,hidden_layer_sizes = clf.best_params_['hidden_layer_sizes'])
train_sizes, train_scores, test_scores = learning_curve(nn, x_train_norm, y_train, cv=n_cv, train_sizes=train_sizes, n_jobs = -1)

train_scores_mean = np.mean(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)
plt.figure()
plt.title("NN on Tree based feature selector Learning Curve - Pulsar Dataset")
plt.xlabel("Length of dataset")
plt.ylabel("Score")
plt.grid()
plt.plot(train_sizes, train_scores_mean, label="Training score")
plt.plot(train_sizes, test_scores_mean, label="Cross-validation score")
plt.legend(loc="best")
plt.show()
# Out:
# Best parameters for Neural Network:
# {'hidden_layer_sizes': (100, 75, 75, 50, 50, 25, 25)}
# Accuracy score of Neural network with best parameters is 98.01%
# ROC score of Neural Network with best parameters is 91.90%
# F1 score of Neural Network with best parameters is 88.63%

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)

plt.title('Receiver Operating Characteristic for NN on Tree based feature selector')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
# Out:
# Text(0.5, 0, 'False Positive Rate')

# %%
X_train, X_test, y_train, y_test = train_test_split( X_reduced_tree, Y, test_size = 0.3)
nn = MLPClassifier(max_iter=2000,early_stopping=True,learning_rate='adaptive',random_state=random_seed
                   ,hidden_layer_sizes = [100, 75, 75, 50, 50])
# %timeit nn.fit(x_train_norm, y_train)

# %timeit nn.predict(x_train_norm)
# Out:
# 1.39 s ± 82.3 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 129 ms ± 16.7 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# # Neural Network on KMeans Clustered Data

# %%
kmeans = KMeans(n_clusters=2, random_state=random_seed, n_jobs = -1)
X_kmeans = kmeans.fit_transform(X)
kmeans_labels = kmeans.predict(X)

x_train_norm, x_test_norm, y_train, y_test = train_test_split( X_kmeans, Y, test_size = 0.3)
seed = 1
n_cv = 5

nn = MLPClassifier(max_iter=2000,early_stopping=True,learning_rate='adaptive',random_state=seed)
hidden_layers = [(100,75,50), (100,75,75,50),(100,75,75,50,50),(100,75,75,50,50,25),(100,75,75,50,50,25,25)]
train_scores, test_scores = validation_curve(nn, x_train_norm, y_train, param_name="hidden_layer_sizes", param_range=hidden_layers, cv=n_cv, n_jobs=-1)

plt.figure()
plt.plot(range(3,len(hidden_layers)+3), np.mean(train_scores, axis=1), label='Training score')
plt.plot(range(3,len(hidden_layers)+3), np.mean(test_scores, axis=1), label='Cross-validation score')
plt.title('NN on KMeans - Pulsar Dataset')
plt.xlabel('number of layers')
plt.ylabel("Score")
plt.legend(loc="best")
plt.grid()
plt.show()

# %%
parameters = {'hidden_layer_sizes' : hidden_layers}
nn = MLPClassifier(max_iter=2000 ,early_stopping=True)
clf = GridSearchCV(nn, param_grid=parameters, cv=n_cv, n_jobs=-1)
clf.fit(x_train_norm, y_train)

print("Best parameters for Neural Network:")
print(clf.best_params_)
y_pred = clf.predict(x_test_norm)
print('Accuracy score of Neural network with best parameters is %.2f%%' % (accuracy_score(y_test, y_pred) * 100))
print('ROC score of Neural Network with best parameters is %.2f%%' % (roc_auc_score(y_test, y_pred) * 100))
print('F1 score of Neural Network with best parameters is %.2f%%' % (f1_score(y_test, y_pred) * 100))

train_sizes=np.linspace(0.2, 1.0, 5)
nn = MLPClassifier(max_iter=2000,early_stopping=True,learning_rate='adaptive',random_state=random_seed
                   ,hidden_layer_sizes = clf.best_params_['hidden_layer_sizes'])
train_sizes, train_scores, test_scores = learning_curve(nn, x_train_norm, y_train, cv=n_cv, train_sizes=train_sizes, n_jobs = -1)

train_scores_mean = np.mean(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)
plt.figure()
plt.title("NN on KMeans Learning Curve - Pulsar Dataset")
plt.xlabel("Length of dataset")
plt.ylabel("Score")
plt.grid()
plt.plot(train_sizes, train_scores_mean, label="Training score")
plt.plot(train_sizes, test_scores_mean, label="Cross-validation score")
plt.legend(loc="best")
plt.show()
# Out:
# Best parameters for Neural Network:
# {'hidden_layer_sizes': (100, 75, 75, 50, 50, 25)}
# Accuracy score of Neural network with best parameters is 96.29%
# ROC score of Neural Network with best parameters is 85.38%
# F1 score of Neural Network with best parameters is 79.12%

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)

plt.title('Receiver Operating Characteristic for NN on KMeans')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
# Out:
# Text(0.5, 0, 'False Positive Rate')

# %%
X_train, X_test, y_train, y_test = train_test_split( X_kmeans, Y, test_size = 0.3)
nn = MLPClassifier(max_iter=2000,early_stopping=True,learning_rate='adaptive',random_state=random_seed
                   ,hidden_layer_sizes = [100, 75, 75, 50, 50])
# %timeit nn.fit(x_train_norm, y_train)

# %timeit nn.predict(x_train_norm)
# Out:
# 1.32 s ± 22 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 88.6 ms ± 29.9 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# # Neural Network on EM Clustered Data

# %%
gmm = GMM(n_components=9,covariance_type='full',random_state=random_seed).fit(X)
gmm_labels = gmm.predict(X)
X_gmm = gmm.predict_proba(X)
sc = StandardScaler()
X_gmm = sc.fit_transform(X_gmm)

x_train_norm, x_test_norm, y_train, y_test = train_test_split( X_gmm, Y, test_size = 0.3)
seed = 1
n_cv = 5

nn = MLPClassifier(max_iter=2000,early_stopping=True,learning_rate='adaptive',random_state=seed)
hidden_layers = [(100,75,50), (100,75,75,50),(100,75,75,50,50),(100,75,75,50,50,25),(100,75,75,50,50,25,25)]
train_scores, test_scores = validation_curve(nn, x_train_norm, y_train, param_name="hidden_layer_sizes", param_range=hidden_layers, cv=n_cv, n_jobs=-1)

plt.figure()
plt.plot(range(3,len(hidden_layers)+3), np.mean(train_scores, axis=1), label='Training score')
plt.plot(range(3,len(hidden_layers)+3), np.mean(test_scores, axis=1), label='Cross-validation score')
plt.title('NN on EM Clustered data - Pulsar Dataset')
plt.xlabel('number of layers')
plt.ylabel("Score")
plt.legend(loc="best")
plt.grid()
plt.show()

# %%
parameters = {'hidden_layer_sizes' : hidden_layers}
nn = MLPClassifier(max_iter=2000 ,early_stopping=True)
clf = GridSearchCV(nn, param_grid=parameters, cv=n_cv, n_jobs=-1)
clf.fit(x_train_norm, y_train)

print("Best parameters for Neural Network:")
print(clf.best_params_)
y_pred = clf.predict(x_test_norm)
print('Accuracy score of Neural network with best parameters is %.2f%%' % (accuracy_score(y_test, y_pred) * 100))
print('ROC score of Neural Network with best parameters is %.2f%%' % (roc_auc_score(y_test, y_pred) * 100))
print('F1 score of Neural Network with best parameters is %.2f%%' % (f1_score(y_test, y_pred) * 100))

train_sizes=np.linspace(0.2, 1.0, 5)
nn = MLPClassifier(max_iter=2000,early_stopping=True,learning_rate='adaptive',random_state=seed
                   ,hidden_layer_sizes = clf.best_params_['hidden_layer_sizes'])
train_sizes, train_scores, test_scores = learning_curve(nn, x_train_norm, y_train, cv=n_cv, train_sizes=train_sizes, n_jobs = -1)

train_scores_mean = np.mean(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)
plt.figure()
plt.title("NN on EM Clustered Data Learning Curve - Pulsar Dataset")
plt.xlabel("Length of dataset")
plt.ylabel("Score")
plt.grid()
plt.plot(train_sizes, train_scores_mean, label="Training score")
plt.plot(train_sizes, test_scores_mean, label="Cross-validation score")
plt.legend(loc="best")
plt.show()
# Out:
# Best parameters for Neural Network:
# {'hidden_layer_sizes': (100, 75, 75, 50, 50, 25, 25)}
# Accuracy score of Neural network with best parameters is 96.82%
# ROC score of Neural Network with best parameters is 86.77%
# F1 score of Neural Network with best parameters is 81.02%

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)

plt.title('Receiver Operating Characteristic for NN on EM Clustered Data')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
# Out:
# Text(0.5, 0, 'False Positive Rate')

# %%
X_train, X_test, y_train, y_test = train_test_split( X_gmm, Y, test_size = 0.3)
sc = StandardScaler()
x_train_norm = sc.fit_transform(X_train)
x_test_norm = sc.transform(X_test)
nn = MLPClassifier(max_iter=2000,early_stopping=True,learning_rate='adaptive',random_state=seed
                   ,hidden_layer_sizes = [100, 75, 75, 50, 50])
# %timeit nn.fit(x_train_norm, y_train)

# %timeit nn.predict(x_train_norm)
# Out:
# 1.86 s ± 159 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 30.1 ms ± 3.23 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
X_train, X_test, y_train, y_test = train_test_split( X, Y, test_size = 0.3)
sc = StandardScaler()
x_train_norm = sc.fit_transform(X_train)
x_test_norm = sc.transform(X_test)
nn = MLPClassifier(max_iter=2000,early_stopping=True,learning_rate='adaptive',random_state=seed
                   ,hidden_layer_sizes = [100, 75, 75, 50, 50])
# %timeit nn.fit(x_train_norm, y_train)

# %timeit nn.predict(x_train_norm)
# Out:
# 3.21 s ± 314 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 32.8 ms ± 1.78 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# fpr, tpr, thresholds = roc_curve(y_test, y_pred)
# roc_auc = auc(fpr, tpr)

# plt.title('Receiver Operating Characteristic for neural network')
# plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
# plt.legend(loc = 'lower right')
# plt.plot([0, 1], [0, 1],'r--')
# plt.xlim([0, 1])
# plt.ylim([0, 1])
# plt.ylabel('True Positive Rate')
# plt.xlabel('False Positive Rate')

# %% [markdown]
# # NN on PCA with K-means

# %%
# x_train_norm, x_test_norm, y_train, y_test = train_test_split( X_clustered_pca_kmeans, Y, test_size = 0.3)

# nn = MLPClassifier(max_iter=2000,early_stopping=True,learning_rate='adaptive',random_state=seed)
# hidden_layers = [(100,75,50), (100,75,75,50),(100,75,75,50,50),(100,75,75,50,50,25),(100,75,75,50,50,25,25)]
# train_scores, test_scores = validation_curve(nn, x_train_norm, y_train, param_name="hidden_layer_sizes", param_range=hidden_layers, cv=n_cv, n_jobs=-1)

# plt.figure()
# plt.plot(range(3,len(hidden_layers)+3), np.mean(train_scores, axis=1), label='Training score')
# plt.plot(range(3,len(hidden_layers)+3), np.mean(test_scores, axis=1), label='Cross-validation score')
# plt.title('NN on PCA with Kmeans - Pulsar Dataset')
# plt.xlabel('number of layers')
# plt.ylabel("Score")
# plt.legend(loc="best")
# plt.grid()
# plt.show()

# %%
# parameters = {'hidden_layer_sizes' : hidden_layers}
# nn = MLPClassifier(max_iter=2000 ,early_stopping=True)
# clf = GridSearchCV(nn, param_grid=parameters, cv=n_cv, n_jobs=-1)
# clf.fit(x_train_norm, y_train)

# print("Best parameters for Neural Network:")
# print(clf.best_params_)
# y_pred = clf.predict(x_test_norm)
# print('Accuracy score of Neural network with best parameters is %.2f%%' % (accuracy_score(y_test, y_pred) * 100))
# print('ROC score of Neural Network with best parameters is %.2f%%' % (roc_auc_score(y_test, y_pred) * 100))
# print('F1 score of Neural Network with best parameters is %.2f%%' % (f1_score(y_test, y_pred) * 100))

# train_sizes=np.linspace(0.2, 1.0, 5)
# nn = MLPClassifier(max_iter=2000,early_stopping=True,learning_rate='adaptive',random_state=seed
#                    ,hidden_layer_sizes = clf.best_params_['hidden_layer_sizes'])
# train_sizes, train_scores, test_scores = learning_curve(nn, x_train_norm, y_train, cv=n_cv, train_sizes=train_sizes, n_jobs = -1)

# train_scores_mean = np.mean(train_scores, axis=1)
# test_scores_mean = np.mean(test_scores, axis=1)
# plt.figure()
# plt.title("NN on PCA with Kmeans Learning Curve - Pulsar Dataset")
# plt.xlabel("Length of dataset")
# plt.ylabel("Score")
# plt.grid()
# plt.plot(train_sizes, train_scores_mean, label="Training score")
# plt.plot(train_sizes, test_scores_mean, label="Cross-validation score")
# plt.legend(loc="best")
# plt.show()

# %%
# fpr, tpr, thresholds = roc_curve(y_test, y_pred)
# roc_auc = auc(fpr, tpr)

# plt.title('Receiver Operating Characteristic for NN on PCA with Kmeans')
# plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
# plt.legend(loc = 'lower right')
# plt.plot([0, 1], [0, 1],'r--')
# plt.xlim([0, 1])
# plt.ylim([0, 1])
# plt.ylabel('True Positive Rate')
# plt.xlabel('False Positive Rate')

# %% [markdown]
# # NN on ICA with K-means

# %%
# x_train_norm, x_test_norm, y_train, y_test = train_test_split( X_clustered_ica_kmeans, Y, test_size = 0.3)

# nn = MLPClassifier(max_iter=2000,early_stopping=True,learning_rate='adaptive',random_state=seed)
# hidden_layers = [(100,75,50), (100,75,75,50),(100,75,75,50,50),(100,75,75,50,50,25),(100,75,75,50,50,25,25)]
# train_scores, test_scores = validation_curve(nn, x_train_norm, y_train, param_name="hidden_layer_sizes", param_range=hidden_layers, cv=n_cv, n_jobs=-1)

# plt.figure()
# plt.plot(range(3,len(hidden_layers)+3), np.mean(train_scores, axis=1), label='Training score')
# plt.plot(range(3,len(hidden_layers)+3), np.mean(test_scores, axis=1), label='Cross-validation score')
# plt.title('NN on ICA with Kmeans - Pulsar Dataset')
# plt.xlabel('number of layers')
# plt.ylabel("Score")
# plt.legend(loc="best")
# plt.grid()
# plt.show()

# %%
# parameters = {'hidden_layer_sizes' : hidden_layers}
# nn = MLPClassifier(max_iter=2000 ,early_stopping=True)
# clf = GridSearchCV(nn, param_grid=parameters, cv=n_cv, n_jobs=-1)
# clf.fit(x_train_norm, y_train)

# print("Best parameters for Neural Network:")
# print(clf.best_params_)
# y_pred = clf.predict(x_test_norm)
# print('Accuracy score of Neural network with best parameters is %.2f%%' % (accuracy_score(y_test, y_pred) * 100))
# print('ROC score of Neural Network with best parameters is %.2f%%' % (roc_auc_score(y_test, y_pred) * 100))
# print('F1 score of Neural Network with best parameters is %.2f%%' % (f1_score(y_test, y_pred) * 100))

# train_sizes=np.linspace(0.2, 1.0, 5)
# nn = MLPClassifier(max_iter=2000,early_stopping=True,learning_rate='adaptive',random_state=seed
#                    ,hidden_layer_sizes = clf.best_params_['hidden_layer_sizes'])
# train_sizes, train_scores, test_scores = learning_curve(nn, x_train_norm, y_train, cv=n_cv, train_sizes=train_sizes, n_jobs = -1)

# train_scores_mean = np.mean(train_scores, axis=1)
# test_scores_mean = np.mean(test_scores, axis=1)
# plt.figure()
# plt.title("NN on ICA with Kmeans Learning Curve - Pulsar Dataset")
# plt.xlabel("Length of dataset")
# plt.ylabel("Score")
# plt.grid()
# plt.plot(train_sizes, train_scores_mean, label="Training score")
# plt.plot(train_sizes, test_scores_mean, label="Cross-validation score")
# plt.legend(loc="best")
# plt.show()

# %%
# fpr, tpr, thresholds = roc_curve(y_test, y_pred)
# roc_auc = auc(fpr, tpr)

# plt.title('Receiver Operating Characteristic for NN on ICA with Kmeans')
# plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
# plt.legend(loc = 'lower right')
# plt.plot([0, 1], [0, 1],'r--')
# plt.xlim([0, 1])
# plt.ylim([0, 1])
# plt.ylabel('True Positive Rate')
# plt.xlabel('False Positive Rate')

# %% [markdown]
# # NN on RCA with K-means

# %%
# x_train_norm, x_test_norm, y_train, y_test = train_test_split( X_clustered_rca_kmeans, Y, test_size = 0.3)

# nn = MLPClassifier(max_iter=2000,early_stopping=True,learning_rate='adaptive',random_state=seed)
# hidden_layers = [(100,75,50), (100,75,75,50),(100,75,75,50,50),(100,75,75,50,50,25),(100,75,75,50,50,25,25)]
# train_scores, test_scores = validation_curve(nn, x_train_norm, y_train, param_name="hidden_layer_sizes", param_range=hidden_layers, cv=n_cv, n_jobs=-1)

# plt.figure()
# plt.plot(range(3,len(hidden_layers)+3), np.mean(train_scores, axis=1), label='Training score')
# plt.plot(range(3,len(hidden_layers)+3), np.mean(test_scores, axis=1), label='Cross-validation score')
# plt.title('NN on RCA with Kmeans - Pulsar Dataset')
# plt.xlabel('number of layers')
# plt.ylabel("Score")
# plt.legend(loc="best")
# plt.grid()
# plt.show()

# %%
# parameters = {'hidden_layer_sizes' : hidden_layers}
# nn = MLPClassifier(max_iter=2000 ,early_stopping=True)
# clf = GridSearchCV(nn, param_grid=parameters, cv=n_cv, n_jobs=-1)
# clf.fit(x_train_norm, y_train)

# print("Best parameters for Neural Network:")
# print(clf.best_params_)
# y_pred = clf.predict(x_test_norm)
# print('Accuracy score of Neural network with best parameters is %.2f%%' % (accuracy_score(y_test, y_pred) * 100))
# print('ROC score of Neural Network with best parameters is %.2f%%' % (roc_auc_score(y_test, y_pred) * 100))
# print('F1 score of Neural Network with best parameters is %.2f%%' % (f1_score(y_test, y_pred) * 100))

# train_sizes=np.linspace(0.2, 1.0, 5)
# nn = MLPClassifier(max_iter=2000,early_stopping=True,learning_rate='adaptive',random_state=seed
#                    ,hidden_layer_sizes = clf.best_params_['hidden_layer_sizes'])
# train_sizes, train_scores, test_scores = learning_curve(nn, x_train_norm, y_train, cv=n_cv, train_sizes=train_sizes, n_jobs = -1)

# train_scores_mean = np.mean(train_scores, axis=1)
# test_scores_mean = np.mean(test_scores, axis=1)
# plt.figure()
# plt.title("NN on RCA with Kmeans Learning Curve - Pulsar Dataset")
# plt.xlabel("Length of dataset")
# plt.ylabel("Score")
# plt.grid()
# plt.plot(train_sizes, train_scores_mean, label="Training score")
# plt.plot(train_sizes, test_scores_mean, label="Cross-validation score")
# plt.legend(loc="best")
# plt.show()

# %%
# fpr, tpr, thresholds = roc_curve(y_test, y_pred)
# roc_auc = auc(fpr, tpr)

# plt.title('Receiver Operating Characteristic for NN on RCA with Kmeans')
# plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
# plt.legend(loc = 'lower right')
# plt.plot([0, 1], [0, 1],'r--')
# plt.xlim([0, 1])
# plt.ylim([0, 1])
# plt.ylabel('True Positive Rate')
# plt.xlabel('False Positive Rate')

# %% [markdown]
# # NN on Tree based Feature Selector with K-means

# %% [markdown]
# # NN on PCA with EM

# %%
# x_train_norm, x_test_norm, y_train, y_test = train_test_split( X_clustered_pca_em, Y, test_size = 0.3)

# nn = MLPClassifier(max_iter=2000,early_stopping=True,learning_rate='adaptive',random_state=seed)
# hidden_layers = [(100,75,50), (100,75,75,50),(100,75,75,50,50),(100,75,75,50,50,25),(100,75,75,50,50,25,25)]
# train_scores, test_scores = validation_curve(nn, x_train_norm, y_train, param_name="hidden_layer_sizes", param_range=hidden_layers, cv=n_cv, n_jobs=-1)

# plt.figure()
# plt.plot(range(3,len(hidden_layers)+3), np.mean(train_scores, axis=1), label='Training score')
# plt.plot(range(3,len(hidden_layers)+3), np.mean(test_scores, axis=1), label='Cross-validation score')
# plt.title('NN on PCA with EM - Pulsar Dataset')
# plt.xlabel('number of layers')
# plt.ylabel("Score")
# plt.legend(loc="best")
# plt.grid()
# plt.show()

# %%
# parameters = {'hidden_layer_sizes' : hidden_layers}
# nn = MLPClassifier(max_iter=2000 ,early_stopping=True)
# clf = GridSearchCV(nn, param_grid=parameters, cv=n_cv, n_jobs=-1)
# clf.fit(x_train_norm, y_train)

# print("Best parameters for Neural Network:")
# print(clf.best_params_)
# y_pred = clf.predict(x_test_norm)
# print('Accuracy score of Neural network with best parameters is %.2f%%' % (accuracy_score(y_test, y_pred) * 100))
# print('ROC score of Neural Network with best parameters is %.2f%%' % (roc_auc_score(y_test, y_pred) * 100))
# print('F1 score of Neural Network with best parameters is %.2f%%' % (f1_score(y_test, y_pred) * 100))

# train_sizes=np.linspace(0.2, 1.0, 5)
# nn = MLPClassifier(max_iter=2000,early_stopping=True,learning_rate='adaptive',random_state=seed
#                    ,hidden_layer_sizes = clf.best_params_['hidden_layer_sizes'])
# train_sizes, train_scores, test_scores = learning_curve(nn, x_train_norm, y_train, cv=n_cv, train_sizes=train_sizes, n_jobs = -1)

# train_scores_mean = np.mean(train_scores, axis=1)
# test_scores_mean = np.mean(test_scores, axis=1)
# plt.figure()
# plt.title("NN on PCA with EM Learning Curve - Pulsar Dataset")
# plt.xlabel("Length of dataset")
# plt.ylabel("Score")
# plt.grid()
# plt.plot(train_sizes, train_scores_mean, label="Training score")
# plt.plot(train_sizes, test_scores_mean, label="Cross-validation score")
# plt.legend(loc="best")
# plt.show()

# %%
# fpr, tpr, thresholds = roc_curve(y_test, y_pred)
# roc_auc = auc(fpr, tpr)

# plt.title('Receiver Operating Characteristic for NN on PCA with EM')
# plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
# plt.legend(loc = 'lower right')
# plt.plot([0, 1], [0, 1],'r--')
# plt.xlim([0, 1])
# plt.ylim([0, 1])
# plt.ylabel('True Positive Rate')
# plt.xlabel('False Positive Rate')

# %% [markdown]
# # NN on ICA with EM

# %%
# x_train_norm, x_test_norm, y_train, y_test = train_test_split( X_clustered_ica_em, Y, test_size = 0.3)

# nn = MLPClassifier(max_iter=2000,early_stopping=True,learning_rate='adaptive',random_state=seed)
# hidden_layers = [(100,75,50), (100,75,75,50),(100,75,75,50,50),(100,75,75,50,50,25),(100,75,75,50,50,25,25)]
# train_scores, test_scores = validation_curve(nn, x_train_norm, y_train, param_name="hidden_layer_sizes", param_range=hidden_layers, cv=n_cv, n_jobs=-1)

# plt.figure()
# plt.plot(range(3,len(hidden_layers)+3), np.mean(train_scores, axis=1), label='Training score')
# plt.plot(range(3,len(hidden_layers)+3), np.mean(test_scores, axis=1), label='Cross-validation score')
# plt.title('NN on ICA with EM - Pulsar Dataset')
# plt.xlabel('number of layers')
# plt.ylabel("Score")
# plt.legend(loc="best")
# plt.grid()
# plt.show()

# %%
# parameters = {'hidden_layer_sizes' : hidden_layers}
# nn = MLPClassifier(max_iter=2000 ,early_stopping=True)
# clf = GridSearchCV(nn, param_grid=parameters, cv=n_cv, n_jobs=-1)
# clf.fit(x_train_norm, y_train)

# print("Best parameters for Neural Network:")
# print(clf.best_params_)
# y_pred = clf.predict(x_test_norm)
# print('Accuracy score of Neural network with best parameters is %.2f%%' % (accuracy_score(y_test, y_pred) * 100))
# print('ROC score of Neural Network with best parameters is %.2f%%' % (roc_auc_score(y_test, y_pred) * 100))
# print('F1 score of Neural Network with best parameters is %.2f%%' % (f1_score(y_test, y_pred) * 100))

# train_sizes=np.linspace(0.2, 1.0, 5)
# nn = MLPClassifier(max_iter=2000,early_stopping=True,learning_rate='adaptive',random_state=seed
#                    ,hidden_layer_sizes = clf.best_params_['hidden_layer_sizes'])
# train_sizes, train_scores, test_scores = learning_curve(nn, x_train_norm, y_train, cv=n_cv, train_sizes=train_sizes, n_jobs = -1)

# train_scores_mean = np.mean(train_scores, axis=1)
# test_scores_mean = np.mean(test_scores, axis=1)
# plt.figure()
# plt.title("NN on ICA with EM Learning Curve - Pulsar Dataset")
# plt.xlabel("Length of dataset")
# plt.ylabel("Score")
# plt.grid()
# plt.plot(train_sizes, train_scores_mean, label="Training score")
# plt.plot(train_sizes, test_scores_mean, label="Cross-validation score")
# plt.legend(loc="best")
# plt.show()

# %%
# fpr, tpr, thresholds = roc_curve(y_test, y_pred)
# roc_auc = auc(fpr, tpr)

# plt.title('Receiver Operating Characteristic for NN on ICA with EM')
# plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
# plt.legend(loc = 'lower right')
# plt.plot([0, 1], [0, 1],'r--')
# plt.xlim([0, 1])
# plt.ylim([0, 1])
# plt.ylabel('True Positive Rate')
# plt.xlabel('False Positive Rate')

# %% [markdown]
# # NN on RCA with EM

# %%
# x_train_norm, x_test_norm, y_train, y_test = train_test_split( X_clustered_rca_em, Y, test_size = 0.3)

# nn = MLPClassifier(max_iter=2000,early_stopping=True,learning_rate='adaptive',random_state=seed)
# hidden_layers = [(100,75,50), (100,75,75,50),(100,75,75,50,50),(100,75,75,50,50,25),(100,75,75,50,50,25,25)]
# train_scores, test_scores = validation_curve(nn, x_train_norm, y_train, param_name="hidden_layer_sizes", param_range=hidden_layers, cv=n_cv, n_jobs=-1)

# plt.figure()
# plt.plot(range(3,len(hidden_layers)+3), np.mean(train_scores, axis=1), label='Training score')
# plt.plot(range(3,len(hidden_layers)+3), np.mean(test_scores, axis=1), label='Cross-validation score')
# plt.title('NN on RCA with EM - Pulsar Dataset')
# plt.xlabel('number of layers')
# plt.ylabel("Score")
# plt.legend(loc="best")
# plt.grid()
# plt.show()

# %%
# parameters = {'hidden_layer_sizes' : hidden_layers}
# nn = MLPClassifier(max_iter=2000 ,early_stopping=True)
# clf = GridSearchCV(nn, param_grid=parameters, cv=n_cv, n_jobs=-1)
# clf.fit(x_train_norm, y_train)

# print("Best parameters for Neural Network:")
# print(clf.best_params_)
# y_pred = clf.predict(x_test_norm)
# print('Accuracy score of Neural network with best parameters is %.2f%%' % (accuracy_score(y_test, y_pred) * 100))
# print('ROC score of Neural Network with best parameters is %.2f%%' % (roc_auc_score(y_test, y_pred) * 100))
# print('F1 score of Neural Network with best parameters is %.2f%%' % (f1_score(y_test, y_pred) * 100))

# train_sizes=np.linspace(0.2, 1.0, 5)
# nn = MLPClassifier(max_iter=2000,early_stopping=True,learning_rate='adaptive',random_state=seed
#                    ,hidden_layer_sizes = clf.best_params_['hidden_layer_sizes'])
# train_sizes, train_scores, test_scores = learning_curve(nn, x_train_norm, y_train, cv=n_cv, train_sizes=train_sizes, n_jobs = -1)

# train_scores_mean = np.mean(train_scores, axis=1)
# test_scores_mean = np.mean(test_scores, axis=1)
# plt.figure()
# plt.title("NN on RCA with EM Learning Curve - Pulsar Dataset")
# plt.xlabel("Length of dataset")
# plt.ylabel("Score")
# plt.grid()
# plt.plot(train_sizes, train_scores_mean, label="Training score")
# plt.plot(train_sizes, test_scores_mean, label="Cross-validation score")
# plt.legend(loc="best")
# plt.show()

# %%
# fpr, tpr, thresholds = roc_curve(y_test, y_pred)
# roc_auc = auc(fpr, tpr)

# plt.title('Receiver Operating Characteristic for NN on RCA with EM')
# plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
# plt.legend(loc = 'lower right')
# plt.plot([0, 1], [0, 1],'r--')
# plt.xlim([0, 1])
# plt.ylim([0, 1])
# plt.ylabel('True Positive Rate')
# plt.xlabel('False Positive Rate')

# %% [markdown]
# # NN on Tree based feature selector with EM
